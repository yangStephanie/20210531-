# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import gc
import math

# %% [markdown]
# ##  function Extract_NER():   Extract NER from receiving text list

# %%
def Extract_NER(ls_textRow):
    from ckiptagger import data_utils, construct_dictionary, WS, POS, NER
    
    # 載入 自訂詞典
    User_Dict = {}
    with open("KCC Data/Dict/KccDict2020.txt","r", encoding='utf-8-sig') as UDicts:
        for udic in UDicts:
            udWord = udic.strip().split(" ")
            if len(udWord) > 1:
                User_Dict[udWord[0]] = udWord[1]
            else:
                User_Dict[udWord[0]] = 10    # 未給定權重者一律賦予預設值 10                
    dictionary = construct_dictionary(User_Dict)
 
    ws = WS("./data")
    pos = POS("./data")
    ner = NER("./data")
    
    #  ls_segRow = ws(ls_textRow) ------------   without User Dictionary
    ls_segRow = ws(ls_textRow, 
                   sentence_segmentation=True,
                   segment_delimiter_set = {",", "。", ":", "?", "!", ";", "、"},
                   coerce_dictionary = dictionary)
    #print("ls_segRow = ", ls_segRow)
    #print("-----------------------------")
    
    del ws
    del WS
    gc.collect()
    ls_posRow = pos(ls_segRow)
    del pos
    del POS
    gc.collect()
    ls_nerRow = ner(ls_segRow,ls_posRow)
    del ner
    del NER
    gc.collect()
    #print("ls_nerRow = ", ls_nerRow)
    #print("-----------------------------")
    return ls_nerRow

# %% [markdown]
# ## 1. Read data from csv or xlsx file

# %%
#讀檔
df_file = pd.read_csv(r"KCC Data/all-news(11554).csv")
print(df_file.columns)
print("-----------------------------------------------------------")
df_file.head(3)
# Out:
# Index(['序號', '日期', '報別', '內容'], dtype='object')
# -----------------------------------------------------------
#    序號         日期    報別                                                 內容
# 0   1  2016/4/18  臺灣時報  馬英九總統昨天上午視察衛武營藝術文化中心，文化部長洪孟啟、工程會副主委顏久榮及高雄市副市長吳...
# 1   2  2016/4/18  臺灣時報  　日本九州熊本縣接連遭強震襲擊，台灣分別捐贈熊本縣政府和日本政府款項，高雄市長陳菊、台南市 ...
# 2   3  2016/4/18  臺灣時報  　壽山動物園為增進動物飼養福祉及保育工作，特設立「高雄市壽山動物園認養辦法」設立動物認養專戶...

# %% [markdown]
# ## 2.  Main function:
# ### 2.1  Pass text data to function "Extract_NER" by row
# ### 2.2  Integrate every 10 NER return rows into one data frame
# ### 2.3  Write frame into small csv after droping duplicate, locating class, filtering short NER, sorting by class..

# %%
#逐筆傳遞欄位 "text"
df_text = df_file["內容"]
print("內容 欄位筆數 = ",len(df_text))
print("------------------------------------------")
ls_class = list()
ls_ner = list()
fileCunt = 0
rowCunt = 0
for i in range(len(df_text)):
    rowCunt += 1
    ls_dfRow = [df_text[i]]
    # print("ls_dfRow = ", ls_dfRow)
    print("Row No = ",str(i))
    entity_list = Extract_NER(ls_dfRow)
    for j in range(len(entity_list[0])):
        seg = entity_list[0].pop()
        # print("seg = ",seg)
        ls_class.append(seg[2])
        ls_ner.append(seg[3])
    #print("===========================================")
    #print("ls_class = ",ls_class)
    #print("ls_ner = ",ls_ner)
    # if i == 5 or rowCunt == 2:
    if i == (len(df_text)-1) or rowCunt == 10:
        fileCunt += 1
        extract_df = pd.DataFrame({'Class':ls_class, 'NER':ls_ner})
        deDup_df = extract_df.drop_duplicates().copy()
        del extract_df
        cate_df = deDup_df.loc[deDup_df['Class'].isin(['LOC','PERSON', 'ORG', 'LAW', 'EVENT','GPE','NORP'])].copy()
        del deDup_df
        filt_df = cate_df[cate_df['NER'].map(len) >= 2].copy()
        del cate_df
        NER_df = filt_df.sort_values(by=['Class']).copy()
        del filt_df
        #print("__________________________________________________________")  
        #print(NER_df)
        print("fileCunt No = ",str(fileCunt))
        # NER_df.to_csv(r"News Data\News NER Out\\NewsNER870_" + str(fileCunt)+ ".csv")
        NER_df.to_csv(r"Ner_end" + str(fileCunt)+ ".csv")
        rowCunt = 0
print("=====================================================================")
print("Totle NER Files = ",fileCunt)
# Out:
# 內容 欄位筆數 =  11554
# ------------------------------------------
# Row No =  0
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  1
# Row No =  2
# Row No =  3
# Row No =  4
# Row No =  5
# Row No =  6
# Row No =  7
# Row No =  8
# Row No =  9
# fileCunt No =  1
# Row No =  10
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  11
# Row No =  12
# Row No =  13
# Row No =  14
# Row No =  15
# Row No =  16
# Row No =  17
# Row No =  18
# Row No =  19
# fileCunt No =  2
# Row No =  20
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  21
# Row No =  22
# Row No =  23
# Row No =  24
# Row No =  25
# Row No =  26
# Row No =  27
# Row No =  28
# Row No =  29
# fileCunt No =  3
# Row No =  30
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  31
# Row No =  32
# Row No =  33
# Row No =  34
# Row No =  35
# Row No =  36
# Row No =  37
# Row No =  38
# Row No =  39
# fileCunt No =  4
# Row No =  40
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  41
# Row No =  42
# Row No =  43
# Row No =  44
# Row No =  45
# Row No =  46
# Row No =  47
# Row No =  48
# Row No =  49
# fileCunt No =  5
# Row No =  50
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  51
# Row No =  52
# Row No =  53
# Row No =  54
# Row No =  55
# Row No =  56
# Row No =  57
# Row No =  58
# Row No =  59
# fileCunt No =  6
# Row No =  60
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  61
# Row No =  62
# Row No =  63
# Row No =  64
# Row No =  65
# Row No =  66
# Row No =  67
# Row No =  68
# Row No =  69
# fileCunt No =  7
# Row No =  70
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  71
# Row No =  72
# Row No =  73
# Row No =  74
# Row No =  75
# Row No =  76
# Row No =  77
# Row No =  78
# Row No =  79
# fileCunt No =  8
# Row No =  80
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  81
# Row No =  82
# Row No =  83
# Row No =  84
# Row No =  85
# Row No =  86
# Row No =  87
# Row No =  88
# Row No =  89
# fileCunt No =  9
# Row No =  90
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  91
# Row No =  92
# Row No =  93
# Row No =  94
# Row No =  95
# Row No =  96
# Row No =  97
# Row No =  98
# Row No =  99
# fileCunt No =  10
# Row No =  100
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  101
# Row No =  102
# Row No =  103
# Row No =  104
# Row No =  105
# Row No =  106
# Row No =  107
# Row No =  108
# Row No =  109
# fileCunt No =  11
# Row No =  110
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  111
# Row No =  112
# Row No =  113
# Row No =  114
# Row No =  115
# Row No =  116
# Row No =  117
# Row No =  118
# Row No =  119
# fileCunt No =  12
# Row No =  120
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  121
# Row No =  122
# Row No =  123
# Row No =  124
# Row No =  125
# Row No =  126
# Row No =  127
# Row No =  128
# Row No =  129
# fileCunt No =  13
# Row No =  130
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  131
# Row No =  132
# Row No =  133
# Row No =  134
# Row No =  135
# Row No =  136
# Row No =  137
# Row No =  138
# Row No =  139
# fileCunt No =  14
# Row No =  140
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  141
# Row No =  142
# Row No =  143
# Row No =  144
# Row No =  145
# Row No =  146
# Row No =  147
# Row No =  148
# Row No =  149
# fileCunt No =  15
# Row No =  150
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  151
# Row No =  152
# Row No =  153
# Row No =  154
# Row No =  155
# Row No =  156
# Row No =  157
# Row No =  158
# Row No =  159
# fileCunt No =  16
# Row No =  160
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  161
# Row No =  162
# Row No =  163
# Row No =  164
# Row No =  165
# Row No =  166
# Row No =  167
# Row No =  168
# Row No =  169
# fileCunt No =  17
# Row No =  170
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  171
# Row No =  172
# Row No =  173
# Row No =  174
# Row No =  175
# Row No =  176
# Row No =  177
# Row No =  178
# Row No =  179
# fileCunt No =  18
# Row No =  180
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  181
# Row No =  182
# Row No =  183
# Row No =  184
# Row No =  185
# Row No =  186
# Row No =  187
# Row No =  188
# Row No =  189
# fileCunt No =  19
# Row No =  190
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  191
# Row No =  192
# Row No =  193
# Row No =  194
# Row No =  195
# Row No =  196
# Row No =  197
# Row No =  198
# Row No =  199
# fileCunt No =  20
# Row No =  200
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  201
# Row No =  202
# Row No =  203
# Row No =  204
# Row No =  205
# Row No =  206
# Row No =  207
# Row No =  208
# Row No =  209
# fileCunt No =  21
# Row No =  210
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  211
# Row No =  212
# Row No =  213
# Row No =  214
# Row No =  215
# Row No =  216
# Row No =  217
# Row No =  218
# Row No =  219
# fileCunt No =  22
# Row No =  220
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  221
# Row No =  222
# Row No =  223
# Row No =  224
# Row No =  225
# Row No =  226
# Row No =  227
# Row No =  228
# Row No =  229
# fileCunt No =  23
# Row No =  230
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  231
# Row No =  232
# Row No =  233
# Row No =  234
# Row No =  235
# Row No =  236
# Row No =  237
# Row No =  238
# Row No =  239
# fileCunt No =  24
# Row No =  240
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  241
# Row No =  242
# Row No =  243
# Row No =  244
# Row No =  245
# Row No =  246
# Row No =  247
# Row No =  248
# Row No =  249
# fileCunt No =  25
# Row No =  250
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  251
# Row No =  252
# Row No =  253
# Row No =  254
# Row No =  255
# Row No =  256
# Row No =  257
# Row No =  258
# Row No =  259
# fileCunt No =  26
# Row No =  260
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  261
# Row No =  262
# Row No =  263
# Row No =  264
# Row No =  265
# Row No =  266
# Row No =  267
# Row No =  268
# Row No =  269
# fileCunt No =  27
# Row No =  270
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  271
# Row No =  272
# Row No =  273
# Row No =  274
# Row No =  275
# Row No =  276
# Row No =  277
# Row No =  278
# Row No =  279
# fileCunt No =  28
# Row No =  280
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  281
# Row No =  282
# Row No =  283
# Row No =  284
# Row No =  285
# Row No =  286
# Row No =  287
# Row No =  288
# Row No =  289
# fileCunt No =  29
# Row No =  290
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  291
# Row No =  292
# Row No =  293
# Row No =  294
# Row No =  295
# Row No =  296
# Row No =  297
# Row No =  298
# Row No =  299
# fileCunt No =  30
# Row No =  300
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  301
# Row No =  302
# Row No =  303
# Row No =  304
# Row No =  305
# Row No =  306
# Row No =  307
# Row No =  308
# Row No =  309
# fileCunt No =  31
# Row No =  310
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  311
# Row No =  312
# Row No =  313
# Row No =  314
# Row No =  315
# Row No =  316
# Row No =  317
# Row No =  318
# Row No =  319
# fileCunt No =  32
# Row No =  320
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  321
# Row No =  322
# Row No =  323
# Row No =  324
# Row No =  325
# Row No =  326
# Row No =  327
# Row No =  328
# Row No =  329
# fileCunt No =  33
# Row No =  330
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  331
# Row No =  332
# Row No =  333
# Row No =  334
# Row No =  335
# Row No =  336
# Row No =  337
# Row No =  338
# Row No =  339
# fileCunt No =  34
# Row No =  340
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  341
# Row No =  342
# Row No =  343
# Row No =  344
# Row No =  345
# Row No =  346
# Row No =  347
# Row No =  348
# Row No =  349
# fileCunt No =  35
# Row No =  350
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  351
# Row No =  352
# Row No =  353
# Row No =  354
# Row No =  355
# Row No =  356
# Row No =  357
# Row No =  358
# Row No =  359
# fileCunt No =  36
# Row No =  360
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  361
# Row No =  362
# Row No =  363
# Row No =  364
# Row No =  365
# Row No =  366
# Row No =  367
# Row No =  368
# Row No =  369
# fileCunt No =  37
# Row No =  370
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  371
# Row No =  372
# Row No =  373
# Row No =  374
# Row No =  375
# Row No =  376
# Row No =  377
# Row No =  378
# Row No =  379
# fileCunt No =  38
# Row No =  380
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  381
# Row No =  382
# Row No =  383
# Row No =  384
# Row No =  385
# Row No =  386
# Row No =  387
# Row No =  388
# Row No =  389
# fileCunt No =  39
# Row No =  390
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  391
# Row No =  392
# Row No =  393
# Row No =  394
# Row No =  395
# Row No =  396
# Row No =  397
# Row No =  398
# Row No =  399
# fileCunt No =  40
# Row No =  400
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  401
# Row No =  402
# Row No =  403
# Row No =  404
# Row No =  405
# Row No =  406
# Row No =  407
# Row No =  408
# Row No =  409
# fileCunt No =  41
# Row No =  410
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  411
# Row No =  412
# Row No =  413
# Row No =  414
# Row No =  415
# Row No =  416
# Row No =  417
# Row No =  418
# Row No =  419
# fileCunt No =  42
# Row No =  420
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  421
# Row No =  422
# Row No =  423
# Row No =  424
# Row No =  425
# Row No =  426
# Row No =  427
# Row No =  428
# Row No =  429
# fileCunt No =  43
# Row No =  430
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  431
# Row No =  432
# Row No =  433
# Row No =  434
# Row No =  435
# Row No =  436
# Row No =  437
# Row No =  438
# Row No =  439
# fileCunt No =  44
# Row No =  440
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  441
# Row No =  442
# Row No =  443
# Row No =  444
# Row No =  445
# Row No =  446
# Row No =  447
# Row No =  448
# Row No =  449
# fileCunt No =  45
# Row No =  450
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  451
# Row No =  452
# Row No =  453
# Row No =  454
# Row No =  455
# Row No =  456
# Row No =  457
# Row No =  458
# Row No =  459
# fileCunt No =  46
# Row No =  460
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  461
# Row No =  462
# Row No =  463
# Row No =  464
# Row No =  465
# Row No =  466
# Row No =  467
# Row No =  468
# Row No =  469
# fileCunt No =  47
# Row No =  470
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  471
# Row No =  472
# Row No =  473
# Row No =  474
# Row No =  475
# Row No =  476
# Row No =  477
# Row No =  478
# Row No =  479
# fileCunt No =  48
# Row No =  480
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  481
# Row No =  482
# Row No =  483
# Row No =  484
# Row No =  485
# Row No =  486
# Row No =  487
# Row No =  488
# Row No =  489
# fileCunt No =  49
# Row No =  490
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  491
# Row No =  492
# Row No =  493
# Row No =  494
# Row No =  495
# Row No =  496
# Row No =  497
# Row No =  498
# Row No =  499
# fileCunt No =  50
# Row No =  500
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  501
# Row No =  502
# Row No =  503
# Row No =  504
# Row No =  505
# Row No =  506
# Row No =  507
# Row No =  508
# Row No =  509
# fileCunt No =  51
# Row No =  510
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  511
# Row No =  512
# Row No =  513
# Row No =  514
# Row No =  515
# Row No =  516
# Row No =  517
# Row No =  518
# Row No =  519
# fileCunt No =  52
# Row No =  520
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  521
# Row No =  522
# Row No =  523
# Row No =  524
# Row No =  525
# Row No =  526
# Row No =  527
# Row No =  528
# Row No =  529
# fileCunt No =  53
# Row No =  530
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  531
# Row No =  532
# Row No =  533
# Row No =  534
# Row No =  535
# Row No =  536
# Row No =  537
# Row No =  538
# Row No =  539
# fileCunt No =  54
# Row No =  540
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  541
# Row No =  542
# Row No =  543
# Row No =  544
# Row No =  545
# Row No =  546
# Row No =  547
# Row No =  548
# Row No =  549
# fileCunt No =  55
# Row No =  550
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  551
# Row No =  552
# Row No =  553
# Row No =  554
# Row No =  555
# Row No =  556
# Row No =  557
# Row No =  558
# Row No =  559
# fileCunt No =  56
# Row No =  560
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  561
# Row No =  562
# Row No =  563
# Row No =  564
# Row No =  565
# Row No =  566
# Row No =  567
# Row No =  568
# Row No =  569
# fileCunt No =  57
# Row No =  570
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  571
# Row No =  572
# Row No =  573
# Row No =  574
# Row No =  575
# Row No =  576
# Row No =  577
# Row No =  578
# Row No =  579
# fileCunt No =  58
# Row No =  580
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  581
# Row No =  582
# Row No =  583
# Row No =  584
# Row No =  585
# Row No =  586
# Row No =  587
# Row No =  588
# Row No =  589
# fileCunt No =  59
# Row No =  590
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# C:\Users\yangs\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Row No =  591
# Row No =  592
# Row No =  593
# Row No =  594
# Row No =  595
# Row No =  596
# Row No =  597
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-90b1a36b0569> in <module>
#      12     # print("ls_dfRow = ", ls_dfRow)
#      13     print("Row No = ",str(i))
# ---> 14     entity_list = Extract_NER(ls_dfRow)
#      15     for j in range(len(entity_list[0])):
#      16         seg = entity_list[0].pop()
#
# <ipython-input-2-64c7567e815f> in Extract_NER(ls_textRow)
#      15     ws = WS("./data")
#      16     pos = POS("./data")
# ---> 17     ner = NER("./data")
#      18
#      19     #  ls_segRow = ws(ls_textRow) ------------   without User Dictionary
#
# ~\anaconda3\lib\site-packages\ckiptagger\api.py in __init__(self, data_dir, disable_cuda)
#     274             model = model_ner.Model(config)
#     275             model.sess = tf.compat.v1.Session()
# --> 276             model.sess.run(tf.compat.v1.global_variables_initializer())
#     277             saver = tf.compat.v1.train.Saver()
#     278             saver.restore(model.sess, os.path.join(data_dir, "model_ner", config.name))
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     965
#     966     try:
# --> 967       result = self._run(None, fetches, feed_dict, options_ptr,
#     968                          run_metadata_ptr)
#     969       if run_metadata:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1188     # or if the call is a partial run that specifies feeds.
#    1189     if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1190       results = self._do_run(handle, final_targets, final_fetches,
#    1191                              feed_dict_tensor, options, run_metadata)
#    1192     else:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1366
#    1367     if handle is None:
# -> 1368       return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1369                            run_metadata)
#    1370     else:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1373   def _do_call(self, fn, *args):
#    1374     try:
# -> 1375       return fn(*args)
#    1376     except errors.OpError as e:
#    1377       message = compat.as_text(e.message)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1357       # Ensure any changes to the graph are reflected in the runtime.
#    1358       self._extend_graph()
# -> 1359       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1360                                       target_list, run_metadata)
#    1361
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1449   def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1450                           run_metadata):
# -> 1451     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1452                                             fetch_list, target_list,
#    1453                                             run_metadata)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3. Integrate all csv files into single data frame

# %%
import glob
# import pandas as pd

# path = r'News Data\News NER OUT'
path = r'nerout'
#allFiles = glob.glob("{}/*.csv".format(path))
allFiles = glob.glob("./*.csv")

li = []
for filename in allFiles:
    df = pd.read_csv(filename, index_col=0, header=0)
    li.append(df)
    print(li) 

nerFrame = pd.concat(li, axis=0, ignore_index=True)
print(len(nerFrame))
nerFrame.groupby('Class').count()
# Out:
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns],        Class              NER
# 5231   EVENT     環境議題車體廣告徵選活動
# 1505   EVENT     小港沿海六里遷村推動小組
# 458    EVENT           九州熊本強震
# 4777   EVENT         小澤征 爾音樂祭
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 3617  PERSON              黃重諺
# 3601  PERSON              李全教
# 3578  PERSON              鄭新助
# 3685  PERSON              顧立雄
# 910   PERSON              陳玫娟
#
# [1143 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns],        Class              NER
# 5231   EVENT     環境議題車體廣告徵選活動
# 1505   EVENT     小港沿海六里遷村推動小組
# 458    EVENT           九州熊本強震
# 4777   EVENT         小澤征 爾音樂祭
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 3617  PERSON              黃重諺
# 3601  PERSON              李全教
# 3578  PERSON              鄭新助
# 3685  PERSON              顧立雄
# 910   PERSON              陳玫娟
#
# [1143 rows x 2 columns],        Class              NER
# 4351   EVENT           議會藝術走廊
# 640    EVENT      幸福家庭、兒童嘉年華會
# 403    EVENT              水門案
# 4385   EVENT       台灣第一屆國際海事展
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 836   PERSON              陳勁甫
# 4343  PERSON              劉瓊芬
# 4338  PERSON               弘一
# 906   PERSON              劉馨正
# 4568  PERSON              范巽綠
#
# [1221 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns],        Class              NER
# 5231   EVENT     環境議題車體廣告徵選活動
# 1505   EVENT     小港沿海六里遷村推動小組
# 458    EVENT           九州熊本強震
# 4777   EVENT         小澤征 爾音樂祭
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 3617  PERSON              黃重諺
# 3601  PERSON              李全教
# 3578  PERSON              鄭新助
# 3685  PERSON              顧立雄
# 910   PERSON              陳玫娟
#
# [1143 rows x 2 columns],        Class              NER
# 4351   EVENT           議會藝術走廊
# 640    EVENT      幸福家庭、兒童嘉年華會
# 403    EVENT              水門案
# 4385   EVENT       台灣第一屆國際海事展
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 836   PERSON              陳勁甫
# 4343  PERSON              劉瓊芬
# 4338  PERSON               弘一
# 906   PERSON              劉馨正
# 4568  PERSON              范巽綠
#
# [1221 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 4629   EVENT  一○五年南區技職教育博覽會
# 3947   EVENT           頒獎典禮
# 1525   EVENT            五二０
# 4354   EVENT   千里錦繡-棉紙藝術撕畫展
# ...      ...            ...
# 4523  PERSON      Cheekwony
# 4521  PERSON         Thomas
# 906   PERSON            劉馨正
# 4563  PERSON            御柱祭
# 5908  PERSON            蔡孟裕
#
# [1279 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns],        Class              NER
# 5231   EVENT     環境議題車體廣告徵選活動
# 1505   EVENT     小港沿海六里遷村推動小組
# 458    EVENT           九州熊本強震
# 4777   EVENT         小澤征 爾音樂祭
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 3617  PERSON              黃重諺
# 3601  PERSON              李全教
# 3578  PERSON              鄭新助
# 3685  PERSON              顧立雄
# 910   PERSON              陳玫娟
#
# [1143 rows x 2 columns],        Class              NER
# 4351   EVENT           議會藝術走廊
# 640    EVENT      幸福家庭、兒童嘉年華會
# 403    EVENT              水門案
# 4385   EVENT       台灣第一屆國際海事展
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 836   PERSON              陳勁甫
# 4343  PERSON              劉瓊芬
# 4338  PERSON               弘一
# 906   PERSON              劉馨正
# 4568  PERSON              范巽綠
#
# [1221 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 4629   EVENT  一○五年南區技職教育博覽會
# 3947   EVENT           頒獎典禮
# 1525   EVENT            五二０
# 4354   EVENT   千里錦繡-棉紙藝術撕畫展
# ...      ...            ...
# 4523  PERSON      Cheekwony
# 4521  PERSON         Thomas
# 906   PERSON            劉馨正
# 4563  PERSON            御柱祭
# 5908  PERSON            蔡孟裕
#
# [1279 rows x 2 columns],        Class            NER
# 560    EVENT           普度法會
# 6284   EVENT           治安會報
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# 4841   EVENT            樂活節
# 4385   EVENT     台灣第一屆國際海事展
# ...      ...            ...
# 3190  PERSON            蕭永
# 3204  PERSON            蔡敏文
# 3221  PERSON            葉菊蘭
# 2946  PERSON            吳麗雪
# 6395  PERSON            莊燦隆
#
# [1414 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns],        Class              NER
# 5231   EVENT     環境議題車體廣告徵選活動
# 1505   EVENT     小港沿海六里遷村推動小組
# 458    EVENT           九州熊本強震
# 4777   EVENT         小澤征 爾音樂祭
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 3617  PERSON              黃重諺
# 3601  PERSON              李全教
# 3578  PERSON              鄭新助
# 3685  PERSON              顧立雄
# 910   PERSON              陳玫娟
#
# [1143 rows x 2 columns],        Class              NER
# 4351   EVENT           議會藝術走廊
# 640    EVENT      幸福家庭、兒童嘉年華會
# 403    EVENT              水門案
# 4385   EVENT       台灣第一屆國際海事展
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 836   PERSON              陳勁甫
# 4343  PERSON              劉瓊芬
# 4338  PERSON               弘一
# 906   PERSON              劉馨正
# 4568  PERSON              范巽綠
#
# [1221 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 4629   EVENT  一○五年南區技職教育博覽會
# 3947   EVENT           頒獎典禮
# 1525   EVENT            五二０
# 4354   EVENT   千里錦繡-棉紙藝術撕畫展
# ...      ...            ...
# 4523  PERSON      Cheekwony
# 4521  PERSON         Thomas
# 906   PERSON            劉馨正
# 4563  PERSON            御柱祭
# 5908  PERSON            蔡孟裕
#
# [1279 rows x 2 columns],        Class            NER
# 560    EVENT           普度法會
# 6284   EVENT           治安會報
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# 4841   EVENT            樂活節
# 4385   EVENT     台灣第一屆國際海事展
# ...      ...            ...
# 3190  PERSON            蕭永
# 3204  PERSON            蔡敏文
# 3221  PERSON            葉菊蘭
# 2946  PERSON            吳麗雪
# 6395  PERSON            莊燦隆
#
# [1414 rows x 2 columns],        Class            NER
# 458    EVENT         九州熊本強震
# 4740   EVENT   全國漆彈大作戰第二波戰火
# 4777   EVENT       小澤征 爾音樂祭
# 4841   EVENT            樂活節
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# ...      ...            ...
# 4884  PERSON            蔡鎮興
# 4889  PERSON            黃文裕
# 485   PERSON            高閔琳
# 4877  PERSON            劉德文
# 5349  PERSON            黃啟川
#
# [1513 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns],        Class              NER
# 5231   EVENT     環境議題車體廣告徵選活動
# 1505   EVENT     小港沿海六里遷村推動小組
# 458    EVENT           九州熊本強震
# 4777   EVENT         小澤征 爾音樂祭
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 3617  PERSON              黃重諺
# 3601  PERSON              李全教
# 3578  PERSON              鄭新助
# 3685  PERSON              顧立雄
# 910   PERSON              陳玫娟
#
# [1143 rows x 2 columns],        Class              NER
# 4351   EVENT           議會藝術走廊
# 640    EVENT      幸福家庭、兒童嘉年華會
# 403    EVENT              水門案
# 4385   EVENT       台灣第一屆國際海事展
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 836   PERSON              陳勁甫
# 4343  PERSON              劉瓊芬
# 4338  PERSON               弘一
# 906   PERSON              劉馨正
# 4568  PERSON              范巽綠
#
# [1221 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 4629   EVENT  一○五年南區技職教育博覽會
# 3947   EVENT           頒獎典禮
# 1525   EVENT            五二０
# 4354   EVENT   千里錦繡-棉紙藝術撕畫展
# ...      ...            ...
# 4523  PERSON      Cheekwony
# 4521  PERSON         Thomas
# 906   PERSON            劉馨正
# 4563  PERSON            御柱祭
# 5908  PERSON            蔡孟裕
#
# [1279 rows x 2 columns],        Class            NER
# 560    EVENT           普度法會
# 6284   EVENT           治安會報
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# 4841   EVENT            樂活節
# 4385   EVENT     台灣第一屆國際海事展
# ...      ...            ...
# 3190  PERSON            蕭永
# 3204  PERSON            蔡敏文
# 3221  PERSON            葉菊蘭
# 2946  PERSON            吳麗雪
# 6395  PERSON            莊燦隆
#
# [1414 rows x 2 columns],        Class            NER
# 458    EVENT         九州熊本強震
# 4740   EVENT   全國漆彈大作戰第二波戰火
# 4777   EVENT       小澤征 爾音樂祭
# 4841   EVENT            樂活節
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# ...      ...            ...
# 4884  PERSON            蔡鎮興
# 4889  PERSON            黃文裕
# 485   PERSON            高閔琳
# 4877  PERSON            劉德文
# 5349  PERSON            黃啟川
#
# [1513 rows x 2 columns],        Class           NER
# 6284   EVENT          治安會報
# 4351   EVENT        議會藝術走廊
# 4340   EVENT  千里錦繡─棉紙藝術撕畫展
# 6062   EVENT         龍潭現金案
# 6575   EVENT           五二○
# ...      ...           ...
# 4313  PERSON           林意翔
# 2496  PERSON            鄭捷
# 5651  PERSON           陳銘彬
# 5746  PERSON           黃日進
# 3394  PERSON            浩鼎
#
# [1579 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns],        Class              NER
# 5231   EVENT     環境議題車體廣告徵選活動
# 1505   EVENT     小港沿海六里遷村推動小組
# 458    EVENT           九州熊本強震
# 4777   EVENT         小澤征 爾音樂祭
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 3617  PERSON              黃重諺
# 3601  PERSON              李全教
# 3578  PERSON              鄭新助
# 3685  PERSON              顧立雄
# 910   PERSON              陳玫娟
#
# [1143 rows x 2 columns],        Class              NER
# 4351   EVENT           議會藝術走廊
# 640    EVENT      幸福家庭、兒童嘉年華會
# 403    EVENT              水門案
# 4385   EVENT       台灣第一屆國際海事展
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 836   PERSON              陳勁甫
# 4343  PERSON              劉瓊芬
# 4338  PERSON               弘一
# 906   PERSON              劉馨正
# 4568  PERSON              范巽綠
#
# [1221 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 4629   EVENT  一○五年南區技職教育博覽會
# 3947   EVENT           頒獎典禮
# 1525   EVENT            五二０
# 4354   EVENT   千里錦繡-棉紙藝術撕畫展
# ...      ...            ...
# 4523  PERSON      Cheekwony
# 4521  PERSON         Thomas
# 906   PERSON            劉馨正
# 4563  PERSON            御柱祭
# 5908  PERSON            蔡孟裕
#
# [1279 rows x 2 columns],        Class            NER
# 560    EVENT           普度法會
# 6284   EVENT           治安會報
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# 4841   EVENT            樂活節
# 4385   EVENT     台灣第一屆國際海事展
# ...      ...            ...
# 3190  PERSON            蕭永
# 3204  PERSON            蔡敏文
# 3221  PERSON            葉菊蘭
# 2946  PERSON            吳麗雪
# 6395  PERSON            莊燦隆
#
# [1414 rows x 2 columns],        Class            NER
# 458    EVENT         九州熊本強震
# 4740   EVENT   全國漆彈大作戰第二波戰火
# 4777   EVENT       小澤征 爾音樂祭
# 4841   EVENT            樂活節
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# ...      ...            ...
# 4884  PERSON            蔡鎮興
# 4889  PERSON            黃文裕
# 485   PERSON            高閔琳
# 4877  PERSON            劉德文
# 5349  PERSON            黃啟川
#
# [1513 rows x 2 columns],        Class           NER
# 6284   EVENT          治安會報
# 4351   EVENT        議會藝術走廊
# 4340   EVENT  千里錦繡─棉紙藝術撕畫展
# 6062   EVENT         龍潭現金案
# 6575   EVENT           五二○
# ...      ...           ...
# 4313  PERSON           林意翔
# 2496  PERSON            鄭捷
# 5651  PERSON           陳銘彬
# 5746  PERSON           黃日進
# 3394  PERSON            浩鼎
#
# [1579 rows x 2 columns],       Class          NER
# 640   EVENT  幸福家庭、兒童嘉年華會
# 403   EVENT          水門案
# 172   EVENT         二次大戰
# 560   EVENT         普度法會
# 458   EVENT       九州熊本強震
# ..      ...          ...
# 450  PERSON          曾俊傑
# 449  PERSON          李順進
# 275  PERSON          明華園
# 528  PERSON          林瑩蓉
# 419  PERSON       愛德華甘迺迪
#
# [254 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns],        Class              NER
# 5231   EVENT     環境議題車體廣告徵選活動
# 1505   EVENT     小港沿海六里遷村推動小組
# 458    EVENT           九州熊本強震
# 4777   EVENT         小澤征 爾音樂祭
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 3617  PERSON              黃重諺
# 3601  PERSON              李全教
# 3578  PERSON              鄭新助
# 3685  PERSON              顧立雄
# 910   PERSON              陳玫娟
#
# [1143 rows x 2 columns],        Class              NER
# 4351   EVENT           議會藝術走廊
# 640    EVENT      幸福家庭、兒童嘉年華會
# 403    EVENT              水門案
# 4385   EVENT       台灣第一屆國際海事展
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 836   PERSON              陳勁甫
# 4343  PERSON              劉瓊芬
# 4338  PERSON               弘一
# 906   PERSON              劉馨正
# 4568  PERSON              范巽綠
#
# [1221 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 4629   EVENT  一○五年南區技職教育博覽會
# 3947   EVENT           頒獎典禮
# 1525   EVENT            五二０
# 4354   EVENT   千里錦繡-棉紙藝術撕畫展
# ...      ...            ...
# 4523  PERSON      Cheekwony
# 4521  PERSON         Thomas
# 906   PERSON            劉馨正
# 4563  PERSON            御柱祭
# 5908  PERSON            蔡孟裕
#
# [1279 rows x 2 columns],        Class            NER
# 560    EVENT           普度法會
# 6284   EVENT           治安會報
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# 4841   EVENT            樂活節
# 4385   EVENT     台灣第一屆國際海事展
# ...      ...            ...
# 3190  PERSON            蕭永
# 3204  PERSON            蔡敏文
# 3221  PERSON            葉菊蘭
# 2946  PERSON            吳麗雪
# 6395  PERSON            莊燦隆
#
# [1414 rows x 2 columns],        Class            NER
# 458    EVENT         九州熊本強震
# 4740   EVENT   全國漆彈大作戰第二波戰火
# 4777   EVENT       小澤征 爾音樂祭
# 4841   EVENT            樂活節
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# ...      ...            ...
# 4884  PERSON            蔡鎮興
# 4889  PERSON            黃文裕
# 485   PERSON            高閔琳
# 4877  PERSON            劉德文
# 5349  PERSON            黃啟川
#
# [1513 rows x 2 columns],        Class           NER
# 6284   EVENT          治安會報
# 4351   EVENT        議會藝術走廊
# 4340   EVENT  千里錦繡─棉紙藝術撕畫展
# 6062   EVENT         龍潭現金案
# 6575   EVENT           五二○
# ...      ...           ...
# 4313  PERSON           林意翔
# 2496  PERSON            鄭捷
# 5651  PERSON           陳銘彬
# 5746  PERSON           黃日進
# 3394  PERSON            浩鼎
#
# [1579 rows x 2 columns],       Class          NER
# 640   EVENT  幸福家庭、兒童嘉年華會
# 403   EVENT          水門案
# 172   EVENT         二次大戰
# 560   EVENT         普度法會
# 458   EVENT       九州熊本強震
# ..      ...          ...
# 450  PERSON          曾俊傑
# 449  PERSON          李順進
# 275  PERSON          明華園
# 528  PERSON          林瑩蓉
# 419  PERSON       愛德華甘迺迪
#
# [254 rows x 2 columns],        Class           NER
# 4363   EVENT        第一屆海事展
# 5231   EVENT  環境議題車體廣告徵選活動
# 172    EVENT          二次大戰
# 7386   EVENT     全國兒童才藝總決賽
# 2896   EVENT  一○五年度南區技職博覽會
# ...      ...           ...
# 1713  PERSON           賴瑞隆
# 5388  PERSON           大溝頂
# 5408  PERSON            史哲
# 1690  PERSON           李賢華
# 7530  PERSON       谷縱·喀勒芳安
#
# [1668 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns],        Class              NER
# 5231   EVENT     環境議題車體廣告徵選活動
# 1505   EVENT     小港沿海六里遷村推動小組
# 458    EVENT           九州熊本強震
# 4777   EVENT         小澤征 爾音樂祭
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 3617  PERSON              黃重諺
# 3601  PERSON              李全教
# 3578  PERSON              鄭新助
# 3685  PERSON              顧立雄
# 910   PERSON              陳玫娟
#
# [1143 rows x 2 columns],        Class              NER
# 4351   EVENT           議會藝術走廊
# 640    EVENT      幸福家庭、兒童嘉年華會
# 403    EVENT              水門案
# 4385   EVENT       台灣第一屆國際海事展
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 836   PERSON              陳勁甫
# 4343  PERSON              劉瓊芬
# 4338  PERSON               弘一
# 906   PERSON              劉馨正
# 4568  PERSON              范巽綠
#
# [1221 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 4629   EVENT  一○五年南區技職教育博覽會
# 3947   EVENT           頒獎典禮
# 1525   EVENT            五二０
# 4354   EVENT   千里錦繡-棉紙藝術撕畫展
# ...      ...            ...
# 4523  PERSON      Cheekwony
# 4521  PERSON         Thomas
# 906   PERSON            劉馨正
# 4563  PERSON            御柱祭
# 5908  PERSON            蔡孟裕
#
# [1279 rows x 2 columns],        Class            NER
# 560    EVENT           普度法會
# 6284   EVENT           治安會報
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# 4841   EVENT            樂活節
# 4385   EVENT     台灣第一屆國際海事展
# ...      ...            ...
# 3190  PERSON            蕭永
# 3204  PERSON            蔡敏文
# 3221  PERSON            葉菊蘭
# 2946  PERSON            吳麗雪
# 6395  PERSON            莊燦隆
#
# [1414 rows x 2 columns],        Class            NER
# 458    EVENT         九州熊本強震
# 4740   EVENT   全國漆彈大作戰第二波戰火
# 4777   EVENT       小澤征 爾音樂祭
# 4841   EVENT            樂活節
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# ...      ...            ...
# 4884  PERSON            蔡鎮興
# 4889  PERSON            黃文裕
# 485   PERSON            高閔琳
# 4877  PERSON            劉德文
# 5349  PERSON            黃啟川
#
# [1513 rows x 2 columns],        Class           NER
# 6284   EVENT          治安會報
# 4351   EVENT        議會藝術走廊
# 4340   EVENT  千里錦繡─棉紙藝術撕畫展
# 6062   EVENT         龍潭現金案
# 6575   EVENT           五二○
# ...      ...           ...
# 4313  PERSON           林意翔
# 2496  PERSON            鄭捷
# 5651  PERSON           陳銘彬
# 5746  PERSON           黃日進
# 3394  PERSON            浩鼎
#
# [1579 rows x 2 columns],       Class          NER
# 640   EVENT  幸福家庭、兒童嘉年華會
# 403   EVENT          水門案
# 172   EVENT         二次大戰
# 560   EVENT         普度法會
# 458   EVENT       九州熊本強震
# ..      ...          ...
# 450  PERSON          曾俊傑
# 449  PERSON          李順進
# 275  PERSON          明華園
# 528  PERSON          林瑩蓉
# 419  PERSON       愛德華甘迺迪
#
# [254 rows x 2 columns],        Class           NER
# 4363   EVENT        第一屆海事展
# 5231   EVENT  環境議題車體廣告徵選活動
# 172    EVENT          二次大戰
# 7386   EVENT     全國兒童才藝總決賽
# 2896   EVENT  一○五年度南區技職博覽會
# ...      ...           ...
# 1713  PERSON           賴瑞隆
# 5388  PERSON           大溝頂
# 5408  PERSON            史哲
# 1690  PERSON           李賢華
# 7530  PERSON       谷縱·喀勒芳安
#
# [1668 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 6062   EVENT          龍潭現金案
# 1206   EVENT  二零一六新加坡國際食 品展
# 6800   EVENT         大同福樂學堂
# 6105   EVENT          新聞夜總會
# ...      ...            ...
# 4598  PERSON             柳平
# 4606  PERSON            曾姿雯
# 6103  PERSON             陳明
# 1121  PERSON            許立明
# 3946  PERSON            李孔文
#
# [1719 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns],        Class              NER
# 5231   EVENT     環境議題車體廣告徵選活動
# 1505   EVENT     小港沿海六里遷村推動小組
# 458    EVENT           九州熊本強震
# 4777   EVENT         小澤征 爾音樂祭
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 3617  PERSON              黃重諺
# 3601  PERSON              李全教
# 3578  PERSON              鄭新助
# 3685  PERSON              顧立雄
# 910   PERSON              陳玫娟
#
# [1143 rows x 2 columns],        Class              NER
# 4351   EVENT           議會藝術走廊
# 640    EVENT      幸福家庭、兒童嘉年華會
# 403    EVENT              水門案
# 4385   EVENT       台灣第一屆國際海事展
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 836   PERSON              陳勁甫
# 4343  PERSON              劉瓊芬
# 4338  PERSON               弘一
# 906   PERSON              劉馨正
# 4568  PERSON              范巽綠
#
# [1221 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 4629   EVENT  一○五年南區技職教育博覽會
# 3947   EVENT           頒獎典禮
# 1525   EVENT            五二０
# 4354   EVENT   千里錦繡-棉紙藝術撕畫展
# ...      ...            ...
# 4523  PERSON      Cheekwony
# 4521  PERSON         Thomas
# 906   PERSON            劉馨正
# 4563  PERSON            御柱祭
# 5908  PERSON            蔡孟裕
#
# [1279 rows x 2 columns],        Class            NER
# 560    EVENT           普度法會
# 6284   EVENT           治安會報
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# 4841   EVENT            樂活節
# 4385   EVENT     台灣第一屆國際海事展
# ...      ...            ...
# 3190  PERSON            蕭永
# 3204  PERSON            蔡敏文
# 3221  PERSON            葉菊蘭
# 2946  PERSON            吳麗雪
# 6395  PERSON            莊燦隆
#
# [1414 rows x 2 columns],        Class            NER
# 458    EVENT         九州熊本強震
# 4740   EVENT   全國漆彈大作戰第二波戰火
# 4777   EVENT       小澤征 爾音樂祭
# 4841   EVENT            樂活節
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# ...      ...            ...
# 4884  PERSON            蔡鎮興
# 4889  PERSON            黃文裕
# 485   PERSON            高閔琳
# 4877  PERSON            劉德文
# 5349  PERSON            黃啟川
#
# [1513 rows x 2 columns],        Class           NER
# 6284   EVENT          治安會報
# 4351   EVENT        議會藝術走廊
# 4340   EVENT  千里錦繡─棉紙藝術撕畫展
# 6062   EVENT         龍潭現金案
# 6575   EVENT           五二○
# ...      ...           ...
# 4313  PERSON           林意翔
# 2496  PERSON            鄭捷
# 5651  PERSON           陳銘彬
# 5746  PERSON           黃日進
# 3394  PERSON            浩鼎
#
# [1579 rows x 2 columns],       Class          NER
# 640   EVENT  幸福家庭、兒童嘉年華會
# 403   EVENT          水門案
# 172   EVENT         二次大戰
# 560   EVENT         普度法會
# 458   EVENT       九州熊本強震
# ..      ...          ...
# 450  PERSON          曾俊傑
# 449  PERSON          李順進
# 275  PERSON          明華園
# 528  PERSON          林瑩蓉
# 419  PERSON       愛德華甘迺迪
#
# [254 rows x 2 columns],        Class           NER
# 4363   EVENT        第一屆海事展
# 5231   EVENT  環境議題車體廣告徵選活動
# 172    EVENT          二次大戰
# 7386   EVENT     全國兒童才藝總決賽
# 2896   EVENT  一○五年度南區技職博覽會
# ...      ...           ...
# 1713  PERSON           賴瑞隆
# 5388  PERSON           大溝頂
# 5408  PERSON            史哲
# 1690  PERSON           李賢華
# 7530  PERSON       谷縱·喀勒芳安
#
# [1668 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 6062   EVENT          龍潭現金案
# 1206   EVENT  二零一六新加坡國際食 品展
# 6800   EVENT         大同福樂學堂
# 6105   EVENT          新聞夜總會
# ...      ...            ...
# 4598  PERSON             柳平
# 4606  PERSON            曾姿雯
# 6103  PERSON             陳明
# 1121  PERSON            許立明
# 3946  PERSON            李孔文
#
# [1719 rows x 2 columns],        Class              NER
# 6320   EVENT           宋江陣頭大賽
# 4385   EVENT       台灣第一屆國際海事展
# 3947   EVENT             頒獎典禮
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# 7386   EVENT        全國兒童才藝總決賽
# ...      ...              ...
# 1934  PERSON              蕭永達
# 1928  PERSON              吳敦義
# 5838  PERSON              許智傑
# 6736  PERSON              北秀峰
# 4167  PERSON              郭志文
#
# [1812 rows x 2 columns]]
# [      Class    NER
# 172   EVENT   二次大戰
# 57      GPE   中華民國
# 60      GPE     熊本
# 71      GPE     台中
# 79      GPE  九州熊本縣
# ..      ...    ...
# 281  PERSON     項羽
# 285  PERSON    孫翠鳳
# 294  PERSON    王永在
# 147  PERSON    蔡復進
# 350  PERSON    劉景寬
#
# [124 rows x 2 columns],        Class      NER
# 1525   EVENT      五二０
# 2335   EVENT   二次世界大戰
# 2322   EVENT  全國黨代表大會
# 2534   EVENT       扁案
# 172    EVENT     二次大戰
# ...      ...      ...
# 996   PERSON      邱議瑩
# 994   PERSON      李永得
# 974   PERSON     陳菊市長
# 951   PERSON      陳麗娜
# 3698  PERSON    議長康裕成
#
# [832 rows x 2 columns],        Class                 NER
# 2123   EVENT              大專足球聯賽
# 2534   EVENT                  扁案
# 1206   EVENT       二零一六新加坡國際食 品展
# 3867   EVENT  高雄環狀輕軌捷運建設第二階段統包工程
# 560    EVENT                普度法會
# ...      ...                 ...
# 533   PERSON                 張漢忠
# 2476  PERSON                 陳其邁
# 2471  PERSON                 管碧玲
# 534   PERSON                 翁瑞珠
# 1556  PERSON                 陳美伶
#
# [898 rows x 2 columns],        Class            NER
# 2534   EVENT             扁案
# 4351   EVENT         議會藝術走廊
# 4340   EVENT   千里錦繡─棉紙藝術撕畫展
# 1206   EVENT  二零一六新加坡國際食 品展
# 2113   EVENT         木蘭足球聯賽
# ...      ...            ...
# 515   PERSON            吳銘賜
# 2929  PERSON            潘孟安
# 516   PERSON            陳明澤
# 3117  PERSON          柯文 哲盼
# 537   PERSON            陳導民
#
# [953 rows x 2 columns],        Class                    NER
# 2165   EVENT                 木蘭女足聯賽
# 1001   EVENT          美濃福安菸葉輔導站整建工程
# 4354   EVENT           千里錦繡-棉紙藝術撕畫展
# 4351   EVENT                 議會藝術走廊
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 3528  PERSON                    陳 菊
# 3506  PERSON                    陳菊市
# 3504  PERSON                    康裕誠
# 3617  PERSON                    黃重諺
# 3394  PERSON                     浩鼎
#
# [1056 rows x 2 columns],        Class              NER
# 5231   EVENT     環境議題車體廣告徵選活動
# 1505   EVENT     小港沿海六里遷村推動小組
# 458    EVENT           九州熊本強震
# 4777   EVENT         小澤征 爾音樂祭
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 3617  PERSON              黃重諺
# 3601  PERSON              李全教
# 3578  PERSON              鄭新助
# 3685  PERSON              顧立雄
# 910   PERSON              陳玫娟
#
# [1143 rows x 2 columns],        Class              NER
# 4351   EVENT           議會藝術走廊
# 640    EVENT      幸福家庭、兒童嘉年華會
# 403    EVENT              水門案
# 4385   EVENT       台灣第一屆國際海事展
# 4381   EVENT  高雄國際海事船舶展暨國防工業展
# ...      ...              ...
# 836   PERSON              陳勁甫
# 4343  PERSON              劉瓊芬
# 4338  PERSON               弘一
# 906   PERSON              劉馨正
# 4568  PERSON              范巽綠
#
# [1221 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 4629   EVENT  一○五年南區技職教育博覽會
# 3947   EVENT           頒獎典禮
# 1525   EVENT            五二０
# 4354   EVENT   千里錦繡-棉紙藝術撕畫展
# ...      ...            ...
# 4523  PERSON      Cheekwony
# 4521  PERSON         Thomas
# 906   PERSON            劉馨正
# 4563  PERSON            御柱祭
# 5908  PERSON            蔡孟裕
#
# [1279 rows x 2 columns],        Class            NER
# 560    EVENT           普度法會
# 6284   EVENT           治安會報
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# 4841   EVENT            樂活節
# 4385   EVENT     台灣第一屆國際海事展
# ...      ...            ...
# 3190  PERSON            蕭永
# 3204  PERSON            蔡敏文
# 3221  PERSON            葉菊蘭
# 2946  PERSON            吳麗雪
# 6395  PERSON            莊燦隆
#
# [1414 rows x 2 columns],        Class            NER
# 458    EVENT         九州熊本強震
# 4740   EVENT   全國漆彈大作戰第二波戰火
# 4777   EVENT       小澤征 爾音樂祭
# 4841   EVENT            樂活節
# 4849   EVENT  你愛水 我節水 歡慶兒童節
# ...      ...            ...
# 4884  PERSON            蔡鎮興
# 4889  PERSON            黃文裕
# 485   PERSON            高閔琳
# 4877  PERSON            劉德文
# 5349  PERSON            黃啟川
#
# [1513 rows x 2 columns],        Class           NER
# 6284   EVENT          治安會報
# 4351   EVENT        議會藝術走廊
# 4340   EVENT  千里錦繡─棉紙藝術撕畫展
# 6062   EVENT         龍潭現金案
# 6575   EVENT           五二○
# ...      ...           ...
# 4313  PERSON           林意翔
# 2496  PERSON            鄭捷
# 5651  PERSON           陳銘彬
# 5746  PERSON           黃日進
# 3394  PERSON            浩鼎
#
# [1579 rows x 2 columns],       Class          NER
# 640   EVENT  幸福家庭、兒童嘉年華會
# 403   EVENT          水門案
# 172   EVENT         二次大戰
# 560   EVENT         普度法會
# 458   EVENT       九州熊本強震
# ..      ...          ...
# 450  PERSON          曾俊傑
# 449  PERSON          李順進
# 275  PERSON          明華園
# 528  PERSON          林瑩蓉
# 419  PERSON       愛德華甘迺迪
#
# [254 rows x 2 columns],        Class           NER
# 4363   EVENT        第一屆海事展
# 5231   EVENT  環境議題車體廣告徵選活動
# 172    EVENT          二次大戰
# 7386   EVENT     全國兒童才藝總決賽
# 2896   EVENT  一○五年度南區技職博覽會
# ...      ...           ...
# 1713  PERSON           賴瑞隆
# 5388  PERSON           大溝頂
# 5408  PERSON            史哲
# 1690  PERSON           李賢華
# 7530  PERSON       谷縱·喀勒芳安
#
# [1668 rows x 2 columns],        Class            NER
# 1505   EVENT   小港沿海六里遷村推動小組
# 6062   EVENT          龍潭現金案
# 1206   EVENT  二零一六新加坡國際食 品展
# 6800   EVENT         大同福樂學堂
# 6105   EVENT          新聞夜總會
# ...      ...            ...
# 4598  PERSON             柳平
# 4606  PERSON            曾姿雯
# 6103  PERSON             陳明
# 1121  PERSON            許立明
# 3946  PERSON            李孔文
#
# [1719 rows x 2 columns],        Class              NER
# 6320   EVENT           宋江陣頭大賽
# 4385   EVENT       台灣第一屆國際海事展
# 3947   EVENT             頒獎典禮
# ...
# 22365   EVENT       中常會
# 13811   EVENT  印尼峇里島迎賓舞
# 13792   EVENT      祝福之舞
# 6284    EVENT      治安會報
# 6320    EVENT    宋江陣頭大賽
# ...       ...       ...
# 5408   PERSON        史哲
# 15049  PERSON       李鴻祥
# 15048  PERSON       蔡明宏
# 5388   PERSON       大溝頂
# 10564  PERSON       藍波安
#
# [4407 rows x 2 columns],        Class          NER
# 2113   EVENT       木蘭足球聯賽
# 2123   EVENT       大專足球聯賽
# 172    EVENT         二次大戰
# 2165   EVENT       木蘭女足聯賽
# 640    EVENT  幸福家庭、兒童嘉年華會
# ...      ...          ...
# 498   PERSON          林芳如
# 497   PERSON          羅鼎城
# 496   PERSON          李柏毅
# 516   PERSON          陳明澤
# 1005  PERSON          黃莉莉
#
# [633 rows x 2 columns],        Class            NER
# 403    EVENT            水門案
# 172    EVENT           二次大戰
# 1525   EVENT            五二０
# 1505   EVENT   小港沿海六里遷村推動小組
# 1206   EVENT  二零一六新加坡國際食 品展
# ...      ...            ...
# 671   PERSON            陳君瑞
# 669   PERSON            陳素月
# 1928  PERSON            吳敦義
# 320   PERSON            黃柏霖
# 389   PERSON             布希
#
# [676 rows x 2 columns],        Class            NER
# 458    EVENT         九州熊本強震
# 2132   EVENT           木蘭聯賽
# 2113   EVENT         木蘭足球聯賽
# 1001   EVENT  美濃福安菸葉輔導站整建工程
# 1525   EVENT            五二０
# ...      ...            ...
# 2110  PERSON            劉福財
# 472   PERSON            林民傑
# 462   PERSON            蔡昌達
# 2088  PERSON            王進焱
# 497   PERSON            羅鼎城
#
# [733 rows x 2 columns],        Class                    NER
# 2374   EVENT                台灣國際扣件展
# 2896   EVENT           一○五年度南區技職博覽會
# 403    EVENT                    水門案
# 2979   EVENT    民進黨第十六屆第一次臨時全國黨代表大會
# 3000   EVENT  民主進步黨第十六屆第一次臨時全國黨代表大會
# ...      ...                    ...
# 961   PERSON                    簡振澄
# 456   PERSON                    康裕成
# 454   PERSON                    吳益政
# 496   PERSON                    李柏毅
# 2121  PERSON                     黃煜
#
# [777 rows x 2 columns],                                             page_id page_name page_category  \
# post_id
# 244784245612709_2052039854887130    244784245612709       陳學聖          政治人物
# 244784245612709_2051705218253927    244784245612709       陳學聖          政治人物
# 244784245612709_2051583111599471    244784245612709       陳學聖          政治人物
# 244784245612709_2050821571675625    244784245612709       陳學聖          政治人物
# 244784245612709_2050423788382070    244784245612709       陳學聖          政治人物
# ...                                             ...       ...           ...
# 1572448819666020_526001401594855   1572448819666020       鄭寶清          公眾人物
# 1572448819666020_818055898640350   1572448819666020       鄭寶清          公眾人物
# 1572448819666020_2485944898316403  1572448819666020       鄭寶清          公眾人物
# 1572448819666020_1485884768227897  1572448819666020       鄭寶清          公眾人物
# 1572448819666020_2439944476321992  1572448819666020       鄭寶清          公眾人物
#
#                                                                              message  \
# post_id
# 244784245612709_2052039854887130   鑒於中油觀塘案在環評大會迅速通關，原先專案小組考量對藻礁生態有重大影響，建議退回目的事業主管...
# 244784245612709_2051705218253927                    聖哥現在在FM91.7❤️\n各位好友，我們一起聽聽聖哥說什麼？
# 244784245612709_2051583111599471   【桃園客家局 慶功宴？泰國行一人八萬！   】\n\n--------------\nhtt...
# 244784245612709_2050821571675625   【FM91.7 POP radio】\n\n各位好友們，今天聖哥中午12:00在FM91.7...
# 244784245612709_2050423788382070   【桃園九歌民族管絃樂團】\n前往排練室為桃園 九歌民族管絃樂團 喝采！從我任文化局長開始，一...
# ...                                                                              ...
# 1572448819666020_526001401594855   📹直播中💡永和市場\n5星級的市長跟5號五告讚的寶清立委一起到永和市場來拜票囉！\n#3張選...
# 1572448819666020_818055898640350   📹直播中💡永和市場\n5星級的市長跟5號五告讚的寶清立委一起到永和市場來拜票囉！\n#3張選...
# 1572448819666020_2485944898316403                                                NaN
# 1572448819666020_1485884768227897  #鼠來寶 #直播第二彈\n再過幾天就要迎接2020，今天初二，來到鎮撫宮參香拜拜，發放大家都...
# 1572448819666020_2439944476321992  #鼠來寶\n再過幾天就要迎接2020，今天初二，第三站來到景福宮參香拜拜，發放大家都喜愛的鼠...
#
#                                        story   type  \
# post_id
# 244784245612709_2052039854887130         NaN  photo
# 244784245612709_2051705218253927         陳學聖  video
# 244784245612709_2051583111599471         NaN   link
# 244784245612709_2050821571675625         NaN  photo
# 244784245612709_2050423788382070         NaN  photo
# ...                                      ...    ...
# 1572448819666020_526001401594855   鄭寶清的直播影片。  video
# 1572448819666020_818055898640350   鄭寶清的直播影片。  video
# 1572448819666020_2485944898316403        NaN  photo
# 1572448819666020_1485884768227897  鄭寶清的直播影片。  video
# 1572448819666020_2439944476321992  鄭寶清的直播影片。  video
#
#                                                                            permalink  \
# post_id
# 244784245612709_2052039854887130   https://www.facebook.com/244784245612709/posts...
# 244784245612709_2051705218253927   https://www.facebook.com/244784245612709/posts...
# 244784245612709_2051583111599471   https://www.facebook.com/244784245612709/posts...
# 244784245612709_2050821571675625   https://www.facebook.com/244784245612709/posts...
# 244784245612709_2050423788382070   https://www.facebook.com/244784245612709/posts...
# ...                                                                              ...
# 1572448819666020_526001401594855   https://www.facebook.com/boching520/videos/526...
# 1572448819666020_818055898640350   https://www.facebook.com/boching520/videos/818...
# 1572448819666020_2485944898316403  https://www.facebook.com/1572448819666020/post...
# 1572448819666020_1485884768227897  https://www.facebook.com/boching520/videos/148...
# 1572448819666020_2439944476321992  https://www.facebook.com/boching520/videos/243...
#
#                                            created_time_gmt  \
# post_id
# 244784245612709_2052039854887130   2019-01-15T11:00:16+0000
# 244784245612709_2051705218253927   2019-01-15T04:07:24+0000
# 244784245612709_2051583111599471   2019-01-15T02:05:12+0000
# 244784245612709_2050821571675625   2019-01-15T00:00:17+0000
# 244784245612709_2050423788382070   2019-01-14T11:00:00+0000
# ...                                                     ...
# 1572448819666020_526001401594855   2019-12-28T00:43:12+0000
# 1572448819666020_818055898640350   2019-12-28T00:13:23+0000
# 1572448819666020_2485944898316403  2019-12-27T09:06:06+0000
# 1572448819666020_1485884768227897  2019-12-27T01:14:40+0000
# 1572448819666020_2439944476321992  2019-12-27T00:07:42+0000
#
#                                    created_time_taipei  \
# post_id
# 244784245612709_2052039854887130   2019-01-15T19:00:16
# 244784245612709_2051705218253927   2019-01-15T12:07:24
# 244784245612709_2051583111599471   2019-01-15T10:05:12
# 244784245612709_2050821571675625   2019-01-15T08:00:17
# 244784245612709_2050423788382070   2019-01-14T19:00:00
# ...                                                ...
# 1572448819666020_526001401594855   2019-12-28T08:43:12
# 1572448819666020_818055898640350   2019-12-28T08:13:23
# 1572448819666020_2485944898316403  2019-12-27T17:06:06
# 1572448819666020_1485884768227897  2019-12-27T09:14:40
# 1572448819666020_2439944476321992  2019-12-27T08:07:42
#
#                                                                             link_url  \
# post_id
# 244784245612709_2052039854887130   https://www.facebook.com/junglicity/photos/a.2...
# 244784245612709_2051705218253927   https://www.facebook.com/FM917popradio/videos/...
# 244784245612709_2051583111599471   https://tw.news.appledaily.com/new/realtime/20...
# 244784245612709_2050821571675625   https://www.facebook.com/junglicity/photos/a.2...
# 244784245612709_2050423788382070   https://www.facebook.com/junglicity/photos/a.2...
# ...                                                                              ...
# 1572448819666020_526001401594855   https://www.facebook.com/boching520/videos/526...
# 1572448819666020_818055898640350   https://www.facebook.com/boching520/videos/818...
# 1572448819666020_2485944898316403  https://www.facebook.com/boching520/photos/a.1...
# 1572448819666020_1485884768227897  https://www.facebook.com/boching520/videos/148...
# 1572448819666020_2439944476321992  https://www.facebook.com/boching520/videos/243...
#
#                                                            link_name  \
# post_id
# 244784245612709_2052039854887130                                 NaN
# 244784245612709_2051705218253927                        POP Radio聯播網
# 244784245612709_2051583111599471   桃園客家局泰國考察每人花8萬　一半團員竟非該局人員！ | 蘋果日報
# 244784245612709_2050821571675625                                 NaN
# 244784245612709_2050423788382070                            陳學聖貼文的相片
# ...                                                              ...
# 1572448819666020_526001401594855                                 NaN
# 1572448819666020_818055898640350                                 NaN
# 1572448819666020_2485944898316403                                NaN
# 1572448819666020_1485884768227897                                NaN
# 1572448819666020_2439944476321992                                NaN
#
#                                                                     link_description  \
# post_id
# 244784245612709_2052039854887130                                                 NaN
# 244784245612709_2051705218253927   【《Pop搶先爆》節目直播📽️】\n♦️主持人：資深媒體人 黃光芹\n♦️來賓：#立法委員 ...
# 244784245612709_2051583111599471   桃園市客家事務局編例118萬7617元共15人，去年12月16日到21日，到泰國進行六天考察...
# 244784245612709_2050821571675625                                                 NaN
# 244784245612709_2050423788382070                                                 NaN
# ...                                                                              ...
# 1572448819666020_526001401594855                                                 NaN
# 1572448819666020_818055898640350                                                 NaN
# 1572448819666020_2485944898316403                                                NaN
# 1572448819666020_1485884768227897                                                NaN
# 1572448819666020_2439944476321992                                                NaN
#
#                                    like_count  haha_count  love_count  \
# post_id
# 244784245612709_2052039854887130          144           0           0
# 244784245612709_2051705218253927          152           0           0
# 244784245612709_2051583111599471          856           0           0
# 244784245612709_2050821571675625          119           0           0
# 244784245612709_2050423788382070          181           0           0
# ...                                       ...         ...         ...
# 1572448819666020_526001401594855          477           0           0
# 1572448819666020_818055898640350          457           0           0
# 1572448819666020_2485944898316403         443           0           0
# 1572448819666020_1485884768227897         485           0           0
# 1572448819666020_2439944476321992         564           0           0
#
#                                    angry_count  sad_count  wow_count  \
# post_id
# 244784245612709_2052039854887130             0          0          0
# 244784245612709_2051705218253927             0          0          0
# 244784245612709_2051583111599471             0          0          0
# 244784245612709_2050821571675625             0          0          0
# 244784245612709_2050423788382070             0          0          0
# ...                                        ...        ...        ...
# 1572448819666020_526001401594855             0          0          0
# 1572448819666020_818055898640350             0          0          0
# 1572448819666020_2485944898316403            0          0          0
# 1572448819666020_1485884768227897            0          0          0
# 1572448819666020_2439944476321992            0          0          0
#
#                                    comment_count  share_count
# post_id
# 244784245612709_2052039854887130               6            5
# 244784245612709_2051705218253927               1            1
# 244784245612709_2051583111599471             129          608
# 244784245612709_2050821571675625               2            0
# 244784245612709_2050423788382070               8            3
# ...                                          ...          ...
# 1572448819666020_526001401594855              39           14
# 1572448819666020_818055898640350              65            9
# 1572448819666020_2485944898316403             31           14
# 1572448819666020_1485884768227897             29           13
# 1572448819666020_2439944476321992             50           12
#
# [28455 rows x 20 columns]]
# 167920
#           NER  page_id  page_name  page_category  message  story  type  \
# Class
# EVENT    5554        0          0              0        0      0     0
# GPE     21326        0          0              0        0      0     0
# LAW      1154        0          0              0        0      0     0
# LOC      8643        0          0              0        0      0     0
# NORP     2740        0          0              0        0      0     0
# ORG     57372        0          0              0        0      0     0
# PERSON  42676        0          0              0        0      0     0
#
#         permalink  created_time_gmt  created_time_taipei  ...  link_name  \
# Class                                                     ...
# EVENT           0                 0                    0  ...          0
# GPE             0                 0                    0  ...          0
# LAW             0                 0                    0  ...          0
# LOC             0                 0                    0  ...          0
# NORP            0                 0                    0  ...          0
# ORG             0                 0                    0  ...          0
# PERSON          0                 0                    0  ...          0
#
#         link_description  like_count  haha_count  love_count  angry_count  \
# Class
# EVENT                  0           0           0           0            0
# GPE                    0           0           0           0            0
# LAW                    0           0           0           0            0
# LOC                    0           0           0           0            0
# NORP                   0           0           0           0            0
# ORG                    0           0           0           0            0
# PERSON                 0           0           0           0            0
#
#         sad_count  wow_count  comment_count  share_count
# Class
# EVENT           0          0              0            0
# GPE             0          0              0            0
# LAW             0          0              0            0
# LOC             0          0              0            0
# NORP            0          0              0            0
# ORG             0          0              0            0
# PERSON          0          0              0            0
#
# [7 rows x 21 columns]

# %% [markdown]
# ## 4. Drop duplicates, group by class and write into csv file

# %%
ddFrame = nerFrame.drop_duplicates().copy()
print(len(ddFrame))
ddFrame.groupby('Class').count()
# Out:
# 31839
#          NER  page_id  page_name  page_category  message  story  type  \
# Class
# EVENT    203        0          0              0        0      0     0
# GPE      633        0          0              0        0      0     0
# LAW       35        0          0              0        0      0     0
# LOC      293        0          0              0        0      0     0
# NORP      86        0          0              0        0      0     0
# ORG     1751        0          0              0        0      0     0
# PERSON  1406        0          0              0        0      0     0
#
#         permalink  created_time_gmt  created_time_taipei  ...  link_name  \
# Class                                                     ...
# EVENT           0                 0                    0  ...          0
# GPE             0                 0                    0  ...          0
# LAW             0                 0                    0  ...          0
# LOC             0                 0                    0  ...          0
# NORP            0                 0                    0  ...          0
# ORG             0                 0                    0  ...          0
# PERSON          0                 0                    0  ...          0
#
#         link_description  like_count  haha_count  love_count  angry_count  \
# Class
# EVENT                  0           0           0           0            0
# GPE                    0           0           0           0            0
# LAW                    0           0           0           0            0
# LOC                    0           0           0           0            0
# NORP                   0           0           0           0            0
# ORG                    0           0           0           0            0
# PERSON                 0           0           0           0            0
#
#         sad_count  wow_count  comment_count  share_count
# Class
# EVENT           0          0              0            0
# GPE             0          0              0            0
# LAW             0          0              0            0
# LOC             0          0              0            0
# NORP            0          0              0            0
# ORG             0          0              0            0
# PERSON          0          0              0            0
#
# [7 rows x 21 columns]

# %%
# ddFrame.sort_values(by=['Class']).to_csv(r"News Data\News NER OUT\\NewsNER.csv")
ddFrame.sort_values(by=['Class']).to_csv(r"nerout")
